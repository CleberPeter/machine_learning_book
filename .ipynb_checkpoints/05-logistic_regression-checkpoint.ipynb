# %% [markdown]
# # Regressão Logística

# %% [markdown]
# Apesar de possuir o termo "Regressão" em seu nome, a Regressão logística é um algoritmo destinado aos problemas de **classificação** cuja saída é discreta, ou seja, $y \in \{0, 1, 2, ...\}$.
#
# A imagem abaixo ilustra um problema clássico de classificação binária. Neste caso o algoritmo deve ser capaz de distinguir entre as duas classes, cachorro(0) e gato(1), dado somente o peso e comprimento do animal.

# %% [markdown]
# <img src="imgs/logistic_regression.png" alt="linear_model" width="800" style="display:block; margin:auto"/>
#
# <div align="center">
# Distinção entre as classes cachorro e gato.
# </div>

# %% [markdown]
# ## Modelo

# %% [markdown]
# Tomando como exemplo a classifição binária, em seguida expandimos o conceito para problemas de classificação multiclasse, a saída $y \in \{0, 1\}$. Uma função que mapeia o conjunto dos reais no intervalo $\{0, 1\}$ é a função **sigmóide**, apresentada e implementada a seguir.

# %% [markdown]
# $$g(z) = \frac{1}{1+e^{-z}}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# logistic function
def sigma(z):
    return 1/(1 + np.exp(-z))

# plot sigma function
m = 100
x = np.linspace(-10, 10, m).reshape(m, 1)
y = sigma(x)

fig = plt.figure(figsize=(20,10))
plt.plot(x, y)
plt.axvline(x = 0, color = 'k')
plt.axhline(y = 0.5, color = 'k')

# %% [markdown]
# Aplicando o modelo linear já desenvolvido para regressão linear na função sigmóide podemos compor um modelo não linear que mapeia as entradas no intervalo $\{0,1\}$.

# %% [markdown]
# $$h_\theta(x) = g(\theta^T x)$$
# $$h_\theta(x) = \frac{1}{1+e^{-\theta^T x}}$$

# %% [markdown]
# O modelo para regressão logística é implementado abaixo.

# %%
# [a b c] -> [1 a b c]
def add_ones_column(x):
    [m, n] = np.shape(x)
    new_x = np.zeros([m, n+1])
    new_x[:,0] = np.ones(m)
    new_x[:,1:] = x[:, 0:]

    return new_x

# logistic regression model
def h(x, o):
    x = add_ones_column(x)
    return sigma(np.dot(x, o))

# %% [markdown]
# Como consequência, a saída do modelo fornecerá não somente a classe estimada, mas também o grau de confiança da estimativa. Afinal $h_\theta(x) = P(y = 1 | x;\theta)$, ou seja, $h_\theta(x)$ indica a probabilidade da saída ser $1$ dado $x$ e $\theta$.
#
# Devido ao caráter binário e portanto complementar da saída, ao estimar a probabilidade de uma das classes também estimamos a da outra. Afinal,  $P(y = 1 | x;\theta) + P(y = 0 | x;\theta) = 1$. Em outras palavras, $h_\theta(x) = 0.7$ indica $70\%$ de probabilidade da saída ser $1$ e $30\%$ dela ser $0$.

# %% [markdown]
# É plausível assumir estimativas iguais ou superiores a $50\%$ como $1$ e inferiores como $0$.
#
# $$h_\theta(x) \geq 0.5 \rightarrow 1$$
# $$h_\theta(x) < 0.5 \rightarrow 0$$

# %% [markdown]
# Ademais, inspecionando o gráfico da função sigmóide podemos verificar que:

# %% [markdown]
# $$g(z) \geq 0.5, \forall z \geq 0$$

# %% [markdown]
# Como consequência:

# %% [markdown]
# $$\theta^T x \geq 0 \rightarrow y = 1$$

# %% [markdown]
# Em outras palavras, a estimativa do modelo será $1$ sempre que o produto $\theta^T x$ for maior ou igual a $0$. Sendo assim, a definição dos parâmetros do modelo em conjunto com a aplicação da função sigmóide resulta em uma **fronteira de decisão**, ilustrada pelo exemplo a seguir.

# %% [markdown]
# ## Fronteira de Decisão

# %% [markdown]
# O modelo $h_\theta(x) = \theta_1 + \theta_2 x_1 + \theta_3 x_2$ de parâmetros $\theta = \begin{bmatrix} -3 & 1 & 1 \end{bmatrix}$ quando empregado em um regressor logístico resulta na seguinte fronteira de decisão:

# %% [markdown]
# $$-3 + x_1 + x_2 \geq 0 \rightarrow y = 1$$
# $$x_1 + x_2 \geq 3 \rightarrow y = 1$$

# %% [markdown]
# <img src="imgs/bondary_decision.png" alt="linear_model" width="200" style="display:block; margin:auto"/>
#
# <div align="center">
# Fronteira de Decisão.
# </div>

# %% [markdown]
# Para o conjunto de dados ilustrado pela figura acima os pontos assinalados com 'x' seriam classificados como pertencentes a classe $1$ e os demais como integrantes da classe $0$.
#
# A complexidade na forma da fronteira é dada pela complexidade do modelo, o modelo $h_\theta(x) = \theta_1 + \theta_2 x_1 + \theta_3 x_2 + \theta_4 x_1^2 + \theta_5 x_2^2$ de parâmetros $\theta = \begin{bmatrix} -1 & 0 & 0 & 1 & 1 \end{bmatrix}$ implica na seguinte fronteira:

# %% [markdown]
# $$x_1^2 + x_2^2 \geq 1 \rightarrow y = 1$$

# %% [markdown]
# <img src="imgs/bondary_decision_1.png" alt="linear_model" width="200" style="display:block; margin:auto"/>
#
# <div align="center">
# Fronteira de Decisão Circular.
# </div>

# %% [markdown]
# ## Otimização

# %% [markdown]
# A definição dos parâmetros que minimizam o custo do modelo na regressão logística é dificultada devido a não linearidade da função sigmóide. Os scripts a seguir ilustram este fato para o modelo $h_\theta(x) = g(\theta_1 + \theta_2 x_1)$ quando utilizada como custo a metade da métrica MSE.

# %%
# MSE/2
def half_MSE(x, o, y):
    m = np.shape(x)[0]
    h_x = h(x, o)
    return np.sum(np.power(h_x - y, 2), axis=0)*1/(2*m)

def plot_cost(x, y, J):
    # arbitrary data to visualize cost function
    m = 100
    o1 = np.linspace(-30, 30, m)
    o2 = o1

    # prepare data in meshgrid format
    X, Y = np.meshgrid(o1, o2)
    
    # serialize meshgrid to use J
    c_o = np.power(len(o1), 2)
    o = np.zeros((2, c_o))
    o[0, :] = np.reshape(X, [1, c_o])
    o[1, :] = np.reshape(Y, [1, c_o])
    j = J(x, o, y)

    # transform j to meshgrid
    Z = np.reshape(j, np.shape(X))
    
    # plot
    fig = plt.figure(figsize=(20,10))
    # surface
    ax = fig.add_subplot(121, projection='3d')
    ax.set_xlabel(r'$\theta_{1}$')
    ax.set_ylabel(r'$\theta_{2}$')
    
    ax.plot_surface(X, Y, Z, alpha=0.2)

# %% [markdown]
# O script a seguir compõem um vetor de saída arbitrário, porém balanceado, isto é, com a mesma quantidade de exemplos de treinamento para cada classe.

# %%
# plot cost function
y = np.zeros(m).reshape(m, 1)
y[int(0.5*m):] = 1
plot_cost(x, y, half_MSE)

# %% [markdown]
# Este exemplo reflete a baixa inclinação da curva de custo em algumas regiões, que ocorre quando nem mesmo uma variação brusca dos parâmetros $\theta$ implicam em alteração no custo do modelo. Afinal, $(y - h_\theta(g(-30 -30x)))^2$ e $(y - h_\theta(g(30 -10 x)))^2$ produzirão saídas semelhantes.
#
# A suavidade quando levada ao limite culmina na multiplicidade de mínimos locais da função custo refletindo sua forma não convexa, como consequência a minimização do através do gradiente descendente é dificultada. Posto isto, uma função custo alternativa é proposta a seguir.

# %% [markdown]
# Com o objetivo de aumentar a penalização do modelo para estimativas erradas e assim aumentar a performance do processo de otimização, a regressão logistíca utiliza a seguinte função custo:
#
# $$J(\theta) = \frac{-1}{m} \sum\limits_{i=1}^{m} y^{i} (log(h_{\theta}(x^{i})) + (1 - y^{i}) (log(1 - h_{\theta}(x^{i}))$$

# %% [markdown]
# O objetivo neste caso é utilizar $- log(h_{\theta}(x))$ como custo quando $y = 1$ e $- log(1 - h_{\theta}(x))$ quando $y = 0$. Conforme pode ser verificado no script abaixo, com esta equação o custo é aumentado de forma logarítmica conforme a diferença entre estimativa $h_{\theta}(x)$ e a saída desejada $y$.

# %%
x = np.linspace(1e-3, 999e-3, 1000)
y_1 = -np.log(x)
y_0 = -np.log(1-x)
fig = plt.figure(figsize=(20,10))
plt.plot(x,y_1)
plt.plot(x,y_0)
plt.xlabel('h(x)')
plt.ylabel('J')
plt.legend(['y = 1', 'y = 0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 x = np.linspace(1e-3, 999e-3, 1e3)
#       2 y_1 = -np.log(x)
#       3 y_0 = -np.log(1-x)
#
# File <__array_function__ internals>:180, in linspace(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/function_base.py:120, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#      23 @array_function_dispatch(_linspace_dispatcher)
#      24 def linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None,
#      25              axis=0):
#      26     """
#      27     Return evenly spaced numbers over a specified interval.
#      28
#    (...)
#     118
#     119     """
# --> 120     num = operator.index(num)
#     121     if num < 0:
#     122         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer
